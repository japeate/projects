# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

from sklearn.metrics import (roc_auc_score, roc_curve, auc, accuracy_score, classification_report, 
confusion_matrix, accuracy_score)

from sklearn.model_selection import (cross_val_score, cross_val_predict, train_test_split, 
StratifiedKFold, GridSearchCV)

from sklearn.linear_model import LogisticRegression, LogisticRegressionCV, SGDClassifier

from sklearn.svm import SVC

from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor

from sklearn.pipeline import Pipeline

from textblob import TextBlob, Word

from nltk import word_tokenize          
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import stopwords

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /Users/mbp15/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/mbp15/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
'''
In this model, I am looking to find the key features from the job description using regression to make predictions
on job salary. This will allow me to find a monetary value associated with each specific skill. I will manually select
top skills from the results and then apply them with random forest regression to determine value of each skill (Question 2,
part 4).
'''

df = pd.read_csv('./seek3.csv', index_col = 0)

# %%
df
# Out:
#                                               job_title job_location  \
# 1                            Data Science Delivery Lead       Sydney
# 3     Machine Learning Engineer / Scientist - Optimi...       Sydney
# 4             Data Analytics & Data Science Team Leader       Sydney
# 8     Senior Data Science (Loyalty) :: $170K + Super...       Sydney
# 9                                 Senior Data Scientist       Sydney
# 11                                       Data Scientist       Sydney
# 15                                       Data Scientist       Sydney
# 18              Senior Business Intelligence Consultant       Sydney
# 27    Research Scientist  - Blockchain and Software ...       Sydney
# 31    Fisheries Economist - Pacific Islands Fisherie...       Sydney
# 35                        Process Automation Specialist       Sydney
# 38                          Clinical Research Associate       Sydney
# 40                                  Credit Risk Analyst       Sydney
# 42                                       Data Scientist       Sydney
# 43                                       Data Scientist       Sydney
# 49    Big Data Engineer (Contract) : Sydney : 6 Mont...       Sydney
# 51                                    Big Data Engineer       Sydney
# 55            Junior digital Marketing Analyst (urgent)       Sydney
# 57    Australian National Audit Office 2020 Graduate...       Sydney
# 58                                       Data Scientist       Sydney
# 65                                      Product Manager       Sydney
# 67                     Data Analyst- Financial Services       Sydney
# 72                      Data Engineer - Spark Streaming       Sydney
# 76                                   Junior SQL Analyst       Sydney
# 81                                  Lead Data Scientist       Sydney
# 82                                Senior Data Scientist       Sydney
# 84                Credit Risk Analytics- Data Scientist       Sydney
# 88                                   Big Data Architect       Sydney
# 90                                       Data Scientist       Sydney
# 91                                     Business Analyst       Sydney
# ...                                                 ...          ...
# 3555                                 Accounts Assistant       Sydney
# 3558               Estimator - Fitout and Refurbishment       Sydney
# 3560                Helpdesk Support - 6 Month Contract       Sydney
# 3562                                 BDM - HVAC Service       Sydney
# 3564                        Mechanical Project Engineer       Sydney
# 3570                Pursuits Specialist/Bid Coordinator       Sydney
# 3571             Administration Assistant - Real-Estate       Sydney
# 3572                                 Software Developer       Sydney
# 3575                          Junior Electrical Drafter       Sydney
# 3576                           Hydraulic Revit Designer       Sydney
# 3577                                     Civil Surveyor       Sydney
# 3579  Construction Surveyors - High-Rise & Infrastru...       Sydney
# 3582            Administration Assistant - Architecture       Sydney
# 3585   Senior Laravel/ Vue Developer - Scalable Product       Sydney
# 3593                            Senior Python Developer       Sydney
# 3594                    Project/Contracts Administrator       Sydney
# 3596                       Senior Technical Lead- COBOL       Sydney
# 3603                                      Administrator       Sydney
# 3607                                 Safety Coordinator       Sydney
# 3620                             Procurement Specialist       Sydney
# 3629              Associate Practice Engagement Manager       Sydney
# 3631                           Assistant Tax Accountant       Sydney
# 3632                  Technical Account Manager | Sales       Sydney
# 3636                                   UI / UX Designer       Sydney
# 3637                     Application Security Architect       Sydney
# 3639                          Fleet Maintenance Officer       Sydney
# 3642        Surveyor - Multi Disciplined Survey Company       Sydney
# 3656                                     L&D Consultant       Sydney
# 3662  Maintenance Scheduler ( 6 to 12 month contract...       Sydney
# 3675       Transmission Lines & Cables Asset Strategist       Sydney
#
#       job_salary                                         advertiser  \
# 1       165000.0                                          Intellify
# 3       160000.0                                         Infopeople
# 4       115046.5                          AUSTRALIAN FEDERAL POLICE
# 8       170000.0                                Correlate Resources
# 9       140000.0                                Preacta Recruitment
# 11      100000.0  Talent – Winner ‘Seek Large Recruitment Agency...
# 15      145000.0                                 Precision Sourcing
# 18       85000.0                                       AI Australia
# 27      167500.0                                              CSIRO
# 31       75074.5                                  Employment Office
# 35      150000.0                                     Robert Walters
# 38      107500.0                                              IQVIA
# 40      100000.0                                  Huxley Associates
# 42      115000.0                      Bluefin Resources Pty Limited
# 43      135000.0                                             Hudson
# 49         950.0                                Correlate Resources
# 51      125000.0                             Hydrogen Group Pty Ltd
# 55       65000.0                                    T+O+M Executive
# 57       60966.0        Australian National Audit Office - Graduate
# 58         750.0                                        Progressive
# 65      150000.0                                          The Onset
# 67         675.0                                        Progressive
# 72         600.0                                Preacta Recruitment
# 76       70000.0                                Correlate Resources
# 81      170000.0  Talent – Winner ‘Seek Large Recruitment Agency...
# 82      130000.0                                FIRESOFT Consulting
# 84         450.0                                        Progressive
# 88      160000.0                             Hydrogen Group Pty Ltd
# 90      115000.0                                             Hudson
# 91         565.0                                             Ignite
# ...          ...                                                ...
# 3555     50000.0                         Hays Accountancy & Finance
# 3558    144999.5                                       Omni Recruit
# 3560        27.5                          Professional Search Group
# 3562    130000.0                                 Austcorp Executive
# 3564    112500.0                                 Cononbrig Partners
# 3570     90000.0                                    Bespoke Careers
# 3571     50000.0                                    CGC Recruitment
# 3572     94999.5                            Data Processors Pty Ltd
# 3575     60000.0                                    CGC Recruitment
# 3576     90000.0                           Redpath Partners Pty Ltd
# 3577    110000.0                                     Design & Build
# 3579    125000.0                  Framework Search & Select Pty Ltd
# 3582     60000.0                                    CGC Recruitment
# 3585    120000.0                         Opus Recruitment Solutions
# 3593    130000.0                         Opus Recruitment Solutions
# 3594     80000.0                             Alexander Appointments
# 3596     94999.5                     HCL Australia Services Pty Ltd
# 3603        29.5                                    CGC Recruitment
# 3607    130000.0                   Constructive Recruitment Pty Ltd
# 3620       700.0                                         Infopeople
# 3629    179999.5                                    Infosys limited
# 3631     59999.5                                Infosys BPM limited
# 3632     75000.0                                 Conductix Wampfler
# 3636    100000.0                         Gomeeki Operations Pty Ltd
# 3637    150000.0                                Ambition Technology
# 3639        45.0                       Symmetry HR - NSW Commercial
# 3642    135000.0                  Framework Search & Select Pty Ltd
# 3656       825.0                             Chandler Macleod Group
# 3662        45.0                               Next Day Recruitment
# 3675       664.5                             Chandler Macleod Group
#
#      search_category                                                url  \
# 1       Data Science  www.seek.com.au/job/38267034?type=standout&sea...
# 3       Data Science  www.seek.com.au/job/38178979?type=standard&sea...
# 4       Data Science  www.seek.com.au/job/38194317?type=standout&sea...
# 8       Data Science  www.seek.com.au/job/38153321?type=standout&sea...
# 9       Data Science  www.seek.com.au/job/38265180?type=standard&sea...
# 11      Data Science  www.seek.com.au/job/38112245?type=standout&sea...
# 15      Data Science  www.seek.com.au/job/38140287?type=standout&sea...
# 18      Data Science  www.seek.com.au/job/38225977?type=standout&sea...
# 27      Data Science  www.seek.com.au/job/38200815?type=standout&sea...
# 31      Data Science  www.seek.com.au/job/38064522?type=standard&sea...
# 35      Data Science  www.seek.com.au/job/38060368?type=standard&sea...
# 38      Data Science  www.seek.com.au/job/38283480?type=standard&sea...
# 40      Data Science  www.seek.com.au/job/38267995?type=standard&sea...
# 42      Data Science  www.seek.com.au/job/38272439?type=standard&sea...
# 43      Data Science  www.seek.com.au/job/38186186?type=standout&sea...
# 49      Data Science  www.seek.com.au/job/38277481?type=standout&sea...
# 51      Data Science  www.seek.com.au/job/38208957?type=standard&sea...
# 55      Data Science  www.seek.com.au/job/38262679?type=standard&sea...
# 57      Data Science  www.seek.com.au/job/38255741?type=standout&sea...
# 58      Data Science  www.seek.com.au/job/38192445?type=standard&sea...
# 65      Data Science  www.seek.com.au/job/38138486?type=standout&sea...
# 67      Data Science  www.seek.com.au/job/38268911?type=standard&sea...
# 72      Data Science  www.seek.com.au/job/38227023?type=standard&sea...
# 76      Data Science  www.seek.com.au/job/38199146?type=standout&sea...
# 81      Data Science  www.seek.com.au/job/38093784?type=standout&sea...
# 82      Data Science  www.seek.com.au/job/38248369?type=standard&sea...
# 84      Data Science  www.seek.com.au/job/38226880?type=standard&sea...
# 88      Data Science  www.seek.com.au/job/38085214?type=standard&sea...
# 90      Data Science  www.seek.com.au/job/38099594?type=standout&sea...
# 91      Data Science  www.seek.com.au/job/38139592?type=standout&sea...
# ...              ...                                                ...
# 3555   Data Engineer  www.seek.com.au/job/38155988?type=standout&sea...
# 3558   Data Engineer  www.seek.com.au/job/38078040?type=standard&sea...
# 3560   Data Engineer  www.seek.com.au/job/38227940?type=standard&sea...
# 3562   Data Engineer  www.seek.com.au/job/38217062?type=standout&sea...
# 3564   Data Engineer  www.seek.com.au/job/38153469?type=standout&sea...
# 3570   Data Engineer  www.seek.com.au/job/38287808?type=standard&sea...
# 3571   Data Engineer  www.seek.com.au/job/38182129?type=standout&sea...
# 3572   Data Engineer  www.seek.com.au/job/37662453?type=standout&sea...
# 3575   Data Engineer  www.seek.com.au/job/38135956?type=standout&sea...
# 3576   Data Engineer  www.seek.com.au/job/38098956?type=standout&sea...
# 3577   Data Engineer  www.seek.com.au/job/38206611?type=standout&sea...
# 3579   Data Engineer  www.seek.com.au/job/38207964?type=standard&sea...
# 3582   Data Engineer  www.seek.com.au/job/38180229?type=standout&sea...
# 3585   Data Engineer  www.seek.com.au/job/38091484?type=standard&sea...
# 3593   Data Engineer  www.seek.com.au/job/38104737?type=standard&sea...
# 3594   Data Engineer  www.seek.com.au/job/38229920?type=standard&sea...
# 3596   Data Engineer  www.seek.com.au/job/38068952?type=standard&sea...
# 3603   Data Engineer  www.seek.com.au/job/38127080?type=standout&sea...
# 3607   Data Engineer  www.seek.com.au/job/38201709?type=standard&sea...
# 3620   Data Engineer  www.seek.com.au/job/38223113?type=standout&sea...
# 3629   Data Engineer  www.seek.com.au/job/38225212?type=standard&sea...
# 3631   Data Engineer  www.seek.com.au/job/37883951?type=standout&sea...
# 3632   Data Engineer  www.seek.com.au/job/38255869?type=standout&sea...
# 3636   Data Engineer  www.seek.com.au/job/38180293?type=standout&sea...
# 3637   Data Engineer  www.seek.com.au/job/38115804?type=standout&sea...
# 3639   Data Engineer  www.seek.com.au/job/38211784?type=standard&sea...
# 3642   Data Engineer  www.seek.com.au/job/38134321?type=standard&sea...
# 3656   Data Engineer  www.seek.com.au/job/38126753?type=standard&sea...
# 3662   Data Engineer  www.seek.com.au/job/38085248?type=standard&sea...
# 3675   Data Engineer  www.seek.com.au/job/38133511?type=standard&sea...
#
#      job_post_date                                           job_desc  \
# 1       5 Feb 2019  About Intellify Intellify is a data science an...
# 3      23 Jan 2019  This role is a newly created role to work with...
# 4      25 Jan 2019  The mission of the AFP is to provide dynamic a...
# 8      21 Jan 2019  Senior Data Scientist (Loyalty) :: $170K + Sup...
# 9       5 Feb 2019  Currently working for one of Australia’s leadi...
# 11     15 Jan 2019  Data Scientist - Cognitive Science & AIJoin th...
# 15     18 Jan 2019  The CompanyThis is one of the most exciting co...
# 18     30 Jan 2019  As a leading Australian owned Artificial Intel...
# 27     25 Jan 2019   Apply your expertise in computer science/soft...
# 31     10 Jan 2019  About the OpportunityFFA has an exciting oppor...
# 35      9 Jan 2019  The Process Automation Specialist will be work...
# 38      8 Jan 2019  IQVIA is committed to bringing clients the bes...
# 40      5 Feb 2019   Responsibilities: Design and development of s...
# 42      5 Feb 2019  One of Australia's leading financial service p...
# 43     24 Jan 2019  About the company Large Education provider bas...
# 49     17 Jan 2019   Big Data Engineer : Initial 6 Month Contract ...
# 51     29 Jan 2019  Job Description: As a key member of a Big Data...
# 55      4 Feb 2019  Since embarking on a major customer transforma...
# 57      4 Feb 2019  About us  The purpose of the ANAO is to drive ...
# 58     24 Jan 2019  Data Scientist - Financial Services- Sydney CB...
# 65     18 Jan 2019  Product ManagerAI/Data Analytics AUD 140,000 -...
# 67      5 Feb 2019  Data Analyst - Financial Services- Sydney CBD-...
# 72     30 Jan 2019  Data Engineer – Spark Streaming  6-month contr...
# 76     25 Jan 2019  Our client is an Australian market leader in t...
# 81     14 Jan 2019  Lead Data Scientist - RetailerA leading Austra...
# 82      1 Feb 2019  Senior Data Scientist - Surry Hills, Sydney, A...
# 84     30 Jan 2019  The Data Scientist will be comfortable prepari...
# 88     11 Jan 2019  Short summary:  Global consulting firm seeks a...
# 90     14 Jan 2019  Focused on helping the business optimise custo...
# 91     18 Jan 2019  A large MSP based in Macquarie Park are curren...
# ...            ...                                                ...
# 3555   21 Jan 2019  Accounts Assistant | North Sydney | Engineerin...
# 3558   11 Jan 2019  A new opportunity with a Growing Team!  Our cl...
# 3560   30 Jan 2019   Help Desk – 6 Month Contract - $25.00 - $30.0...
# 3562   29 Jan 2019  The Client:I am currently working very closely...
# 3564   21 Jan 2019   About the business and the role  Diverse rang...
# 3570   10 Jan 2019  This global architecture and design practice w...
# 3571   23 Jan 2019  Summary   CGC Recruitment is a specialist recr...
# 3572   23 Jan 2019  Data Processors is a data centric research and...
# 3575   18 Jan 2019  The companyOur client is market leading multin...
# 3576   14 Jan 2019  This position is working on behalf of the most...
# 3577   28 Jan 2019  Civil Surveyor   My client is a reputable comp...
# 3579   28 Jan 2019  Construction Surveyors – High-Rise & Infrastru...
# 3582   23 Jan 2019  Summary   CGC Recruitment is a specialist recr...
# 3585   14 Jan 2019  As a Software Engineer, you will develop new p...
# 3593   15 Jan 2019  Become a key part to a Tech start-upFast-track...
# 3594   31 Jan 2019   Excellent position for experienced Project Ad...
# 3596   10 Jan 2019  HCL Technologies is a global transformational ...
# 3603   17 Jan 2019  Summary CGC Recruitment is a specialist recrui...
# 3607   25 Jan 2019  Supportive Team Structure Growing Organisation...
# 3620   30 Jan 2019  The Senior Category Officer ICT is responsible...
# 3629   30 Jan 2019  Infosys – Global Markets The Global Markets te...
# 3631   25 Jan 2019  In this role, you will act as an expert on tax...
# 3632    4 Feb 2019  About Us:  Conductix-Wampfler is Australia's l...
# 3636   23 Jan 2019  This is an outstanding opportunity to join one...
# 3637   16 Jan 2019  Opportunity:Join a world leading multinational...
# 3639   29 Jan 2019  Our client is one of three government operatin...
# 3642   17 Jan 2019  Surveyor – Multi Disciplined Survey Company   ...
# 3656   17 Jan 2019  The Regulatory Transformation Program represen...
# 3662   11 Jan 2019  Client & You:  Engineering Company on the Nort...
# 3675   17 Jan 2019  Chandler Macleod is the leading provider of te...
#
#                                             salary_desc  super     payt2  \
# 1                           $150,000 - $180,000 package    1.0  165000.0
# 3                       Circa upto 160k based on skills    1.0  160000.0
# 4                             $110,172.00 - $119,921.00    1.0  115046.5
# 8                                    $170K+Super+ Bonus    1.1  170000.0
# 9                                  $120,000 to $160,000    1.0  140000.0
# 11                        $80000.00 - $120000 per annum    1.0  100000.0
# 15                                   $130k - $160k p.a.    1.0  145000.0
# 18                                    $75,000 - $95,000    1.0   85000.0
# 27                    $134K - $201K + up to 15.4% super    1.1  167500.0
# 31    USD $64,018-$86,131 + accommodation & relocation!    1.0   75074.5
# 35                                   $140k - $160k p.a.    1.0  150000.0
# 38            $90,000 - $125,000 salary package + super    1.1  107500.0
# 40                                    $90k - $110k p.a.    1.0  100000.0
# 42        $110k - $120k p.a. + super + bonus + benefits    1.1  115000.0
# 43                           Up to $135k p.a. + package    1.0  135000.0
# 49                                   $900-$1000 per day    1.0  346750.0
# 51    £120000.00 - £130000.00 p.a. + plus super and ...    1.1  125000.0
# 55                            $60,000 - $70,000 + super    1.1   65000.0
# 57                                              $60,966    1.0   60966.0
# 58                       $650 - $850 p.d. + competitive    1.0  273750.0
# 65                    AUD 140,000 - AUD 160,000 + Super    1.1  150000.0
# 67                       $650 - $700 p.d. + competitive    1.0  246375.0
# 72                                         $500 to $700    1.0  219000.0
# 76                                              $65-75k    1.0   70000.0
# 81                    $160000.00 - $180000.00 per annum    1.0  170000.0
# 82                                     $1k - $160k p.a.    1.0  130000.0
# 84                       $400 - $500 p.d. + competitive    1.0  164250.0
# 88    £150000.00 - £170000.00 p.a. + plus super and ...    1.1  160000.0
# 90                           $100k - $130k p.a. + Super    1.1  115000.0
# 91     $500 - $630 per day, Bens: Large MSP; Close to p    1.0  206225.0
# ...                                                 ...    ...       ...
# 3555                                       $50k + super    1.1   50000.0
# 3558                                $120,000 - $169,999    1.0  144999.5
# 3560                           $25.00 - $30.00 per hour    1.0   57200.0
# 3562                  $120-140k+ plus package inc comss    1.0  130000.0
# 3564           $100,000 - $125,000 Total Salary Package    1.0  112500.0
# 3570                         $80,000 - $100,000 + Super    1.1   90000.0
# 3571                                       $50k + Super    1.1   50000.0
# 3572                                  $90,000 - $99,999    1.0   94999.5
# 3575                                    55,000 - 65,000    1.0   60000.0
# 3576                         $80,000 - $100,000 package    1.0   90000.0
# 3577  $90k - $130k + super (negotiable depending on ...    1.1  110000.0
# 3579                                     To $125k + O/T    1.0  125000.0
# 3582                                       $60k + Super    1.1   60000.0
# 3585                        $110000 - $130000 per annum    1.0  120000.0
# 3593           $120000 - $140000 per annum, Bens: Super    1.1  130000.0
# 3594    Up to $80k, negotiable, depending on experience    1.0   80000.0
# 3596                                 $80,000 - $109,999    1.0   94999.5
# 3603                $27 - $32 Per hour + Superannuation    1.1   61360.0
# 3607                                Up to $130k + super    1.1  130000.0
# 3620                        $600 - $800 per day + Super    1.1  255500.0
# 3629                                $160,000 - $199,999    1.0  179999.5
# 3631                                  $55,000 - $64,999    1.0   59999.5
# 3632                 $70-$80K + Super + Incentive Bonus    1.1   75000.0
# 3636                                 $90,000 - $110,000    1.0  100000.0
# 3637                     Up to $150000.00 p.a. +  bonus    1.0  150000.0
# 3639                                    $45/hr + Super!    1.1   93600.0
# 3642                           To $135k + O/T + Vehicle    1.0  135000.0
# 3656                                   $800 - $850 p.d.    1.0  301125.0
# 3662        $40 to $50 per hour, 9 to 12 month contract    1.0   93600.0
# 3675                                   $577 - $752 p.d.    1.0  242542.5
#
#       pay_total2
# 1       165000.0
# 3       160000.0
# 4       115046.5
# 8       187000.0
# 9       140000.0
# 11      100000.0
# 15      145000.0
# 18       85000.0
# 27      184250.0
# 31       75074.5
# 35      150000.0
# 38      118250.0
# 40      100000.0
# 42      126500.0
# 43      135000.0
# 49      346750.0
# 51      137500.0
# 55       71500.0
# 57       60966.0
# 58      273750.0
# 65      165000.0
# 67      246375.0
# 72      219000.0
# 76       70000.0
# 81      170000.0
# 82      130000.0
# 84      164250.0
# 88      176000.0
# 90      126500.0
# 91      206225.0
# ...          ...
# 3555     55000.0
# 3558    144999.5
# 3560     57200.0
# 3562    130000.0
# 3564    112500.0
# 3570     99000.0
# 3571     55000.0
# 3572     94999.5
# 3575     60000.0
# 3576     90000.0
# 3577    121000.0
# 3579    125000.0
# 3582     66000.0
# 3585    120000.0
# 3593    143000.0
# 3594     80000.0
# 3596     94999.5
# 3603     67496.0
# 3607    143000.0
# 3620    281050.0
# 3629    179999.5
# 3631     59999.5
# 3632     82500.0
# 3636    100000.0
# 3637    150000.0
# 3639    102960.0
# 3642    135000.0
# 3656    301125.0
# 3662     93600.0
# 3675    242542.5
#
# [1217 rows x 12 columns]

# %%
df.drop(['job_location', 'url', 'search_category', 'job_post_date', 'job_salary', 'salary_desc', 'super', 'payt2'], axis=1, inplace=True)

# %%
df
# Out:
#                                               job_title  \
# 1                            Data Science Delivery Lead
# 3     Machine Learning Engineer / Scientist - Optimi...
# 4             Data Analytics & Data Science Team Leader
# 8     Senior Data Science (Loyalty) :: $170K + Super...
# 9                                 Senior Data Scientist
# 11                                       Data Scientist
# 15                                       Data Scientist
# 18              Senior Business Intelligence Consultant
# 27    Research Scientist  - Blockchain and Software ...
# 31    Fisheries Economist - Pacific Islands Fisherie...
# 35                        Process Automation Specialist
# 38                          Clinical Research Associate
# 40                                  Credit Risk Analyst
# 42                                       Data Scientist
# 43                                       Data Scientist
# 49    Big Data Engineer (Contract) : Sydney : 6 Mont...
# 51                                    Big Data Engineer
# 55            Junior digital Marketing Analyst (urgent)
# 57    Australian National Audit Office 2020 Graduate...
# 58                                       Data Scientist
# 65                                      Product Manager
# 67                     Data Analyst- Financial Services
# 72                      Data Engineer - Spark Streaming
# 76                                   Junior SQL Analyst
# 81                                  Lead Data Scientist
# 82                                Senior Data Scientist
# 84                Credit Risk Analytics- Data Scientist
# 88                                   Big Data Architect
# 90                                       Data Scientist
# 91                                     Business Analyst
# ...                                                 ...
# 3555                                 Accounts Assistant
# 3558               Estimator - Fitout and Refurbishment
# 3560                Helpdesk Support - 6 Month Contract
# 3562                                 BDM - HVAC Service
# 3564                        Mechanical Project Engineer
# 3570                Pursuits Specialist/Bid Coordinator
# 3571             Administration Assistant - Real-Estate
# 3572                                 Software Developer
# 3575                          Junior Electrical Drafter
# 3576                           Hydraulic Revit Designer
# 3577                                     Civil Surveyor
# 3579  Construction Surveyors - High-Rise & Infrastru...
# 3582            Administration Assistant - Architecture
# 3585   Senior Laravel/ Vue Developer - Scalable Product
# 3593                            Senior Python Developer
# 3594                    Project/Contracts Administrator
# 3596                       Senior Technical Lead- COBOL
# 3603                                      Administrator
# 3607                                 Safety Coordinator
# 3620                             Procurement Specialist
# 3629              Associate Practice Engagement Manager
# 3631                           Assistant Tax Accountant
# 3632                  Technical Account Manager | Sales
# 3636                                   UI / UX Designer
# 3637                     Application Security Architect
# 3639                          Fleet Maintenance Officer
# 3642        Surveyor - Multi Disciplined Survey Company
# 3656                                     L&D Consultant
# 3662  Maintenance Scheduler ( 6 to 12 month contract...
# 3675       Transmission Lines & Cables Asset Strategist
#
#                                              advertiser  \
# 1                                             Intellify
# 3                                            Infopeople
# 4                             AUSTRALIAN FEDERAL POLICE
# 8                                   Correlate Resources
# 9                                   Preacta Recruitment
# 11    Talent – Winner ‘Seek Large Recruitment Agency...
# 15                                   Precision Sourcing
# 18                                         AI Australia
# 27                                                CSIRO
# 31                                    Employment Office
# 35                                       Robert Walters
# 38                                                IQVIA
# 40                                    Huxley Associates
# 42                        Bluefin Resources Pty Limited
# 43                                               Hudson
# 49                                  Correlate Resources
# 51                               Hydrogen Group Pty Ltd
# 55                                      T+O+M Executive
# 57          Australian National Audit Office - Graduate
# 58                                          Progressive
# 65                                            The Onset
# 67                                          Progressive
# 72                                  Preacta Recruitment
# 76                                  Correlate Resources
# 81    Talent – Winner ‘Seek Large Recruitment Agency...
# 82                                  FIRESOFT Consulting
# 84                                          Progressive
# 88                               Hydrogen Group Pty Ltd
# 90                                               Hudson
# 91                                               Ignite
# ...                                                 ...
# 3555                         Hays Accountancy & Finance
# 3558                                       Omni Recruit
# 3560                          Professional Search Group
# 3562                                 Austcorp Executive
# 3564                                 Cononbrig Partners
# 3570                                    Bespoke Careers
# 3571                                    CGC Recruitment
# 3572                            Data Processors Pty Ltd
# 3575                                    CGC Recruitment
# 3576                           Redpath Partners Pty Ltd
# 3577                                     Design & Build
# 3579                  Framework Search & Select Pty Ltd
# 3582                                    CGC Recruitment
# 3585                         Opus Recruitment Solutions
# 3593                         Opus Recruitment Solutions
# 3594                             Alexander Appointments
# 3596                     HCL Australia Services Pty Ltd
# 3603                                    CGC Recruitment
# 3607                   Constructive Recruitment Pty Ltd
# 3620                                         Infopeople
# 3629                                    Infosys limited
# 3631                                Infosys BPM limited
# 3632                                 Conductix Wampfler
# 3636                         Gomeeki Operations Pty Ltd
# 3637                                Ambition Technology
# 3639                       Symmetry HR - NSW Commercial
# 3642                  Framework Search & Select Pty Ltd
# 3656                             Chandler Macleod Group
# 3662                               Next Day Recruitment
# 3675                             Chandler Macleod Group
#
#                                                job_desc  pay_total2
# 1     About Intellify Intellify is a data science an...    165000.0
# 3     This role is a newly created role to work with...    160000.0
# 4     The mission of the AFP is to provide dynamic a...    115046.5
# 8     Senior Data Scientist (Loyalty) :: $170K + Sup...    187000.0
# 9     Currently working for one of Australia’s leadi...    140000.0
# 11    Data Scientist - Cognitive Science & AIJoin th...    100000.0
# 15    The CompanyThis is one of the most exciting co...    145000.0
# 18    As a leading Australian owned Artificial Intel...     85000.0
# 27     Apply your expertise in computer science/soft...    184250.0
# 31    About the OpportunityFFA has an exciting oppor...     75074.5
# 35    The Process Automation Specialist will be work...    150000.0
# 38    IQVIA is committed to bringing clients the bes...    118250.0
# 40     Responsibilities: Design and development of s...    100000.0
# 42    One of Australia's leading financial service p...    126500.0
# 43    About the company Large Education provider bas...    135000.0
# 49     Big Data Engineer : Initial 6 Month Contract ...    346750.0
# 51    Job Description: As a key member of a Big Data...    137500.0
# 55    Since embarking on a major customer transforma...     71500.0
# 57    About us  The purpose of the ANAO is to drive ...     60966.0
# 58    Data Scientist - Financial Services- Sydney CB...    273750.0
# 65    Product ManagerAI/Data Analytics AUD 140,000 -...    165000.0
# 67    Data Analyst - Financial Services- Sydney CBD-...    246375.0
# 72    Data Engineer – Spark Streaming  6-month contr...    219000.0
# 76    Our client is an Australian market leader in t...     70000.0
# 81    Lead Data Scientist - RetailerA leading Austra...    170000.0
# 82    Senior Data Scientist - Surry Hills, Sydney, A...    130000.0
# 84    The Data Scientist will be comfortable prepari...    164250.0
# 88    Short summary:  Global consulting firm seeks a...    176000.0
# 90    Focused on helping the business optimise custo...    126500.0
# 91    A large MSP based in Macquarie Park are curren...    206225.0
# ...                                                 ...         ...
# 3555  Accounts Assistant | North Sydney | Engineerin...     55000.0
# 3558  A new opportunity with a Growing Team!  Our cl...    144999.5
# 3560   Help Desk – 6 Month Contract - $25.00 - $30.0...     57200.0
# 3562  The Client:I am currently working very closely...    130000.0
# 3564   About the business and the role  Diverse rang...    112500.0
# 3570  This global architecture and design practice w...     99000.0
# 3571  Summary   CGC Recruitment is a specialist recr...     55000.0
# 3572  Data Processors is a data centric research and...     94999.5
# 3575  The companyOur client is market leading multin...     60000.0
# 3576  This position is working on behalf of the most...     90000.0
# 3577  Civil Surveyor   My client is a reputable comp...    121000.0
# 3579  Construction Surveyors – High-Rise & Infrastru...    125000.0
# 3582  Summary   CGC Recruitment is a specialist recr...     66000.0
# 3585  As a Software Engineer, you will develop new p...    120000.0
# 3593  Become a key part to a Tech start-upFast-track...    143000.0
# 3594   Excellent position for experienced Project Ad...     80000.0
# 3596  HCL Technologies is a global transformational ...     94999.5
# 3603  Summary CGC Recruitment is a specialist recrui...     67496.0
# 3607  Supportive Team Structure Growing Organisation...    143000.0
# 3620  The Senior Category Officer ICT is responsible...    281050.0
# 3629  Infosys – Global Markets The Global Markets te...    179999.5
# 3631  In this role, you will act as an expert on tax...     59999.5
# 3632  About Us:  Conductix-Wampfler is Australia's l...     82500.0
# 3636  This is an outstanding opportunity to join one...    100000.0
# 3637  Opportunity:Join a world leading multinational...    150000.0
# 3639  Our client is one of three government operatin...    102960.0
# 3642  Surveyor – Multi Disciplined Survey Company   ...    135000.0
# 3656  The Regulatory Transformation Program represen...    301125.0
# 3662  Client & You:  Engineering Company on the Nort...     93600.0
# 3675  Chandler Macleod is the leading provider of te...    242542.5
#
# [1217 rows x 4 columns]

# %%
df.job_desc = df.job_desc.str.replace(',', '')
df.job_desc = df.job_desc.str.replace('$', '')
df.job_desc = df.job_desc.str.replace('-', '')
df.job_desc = df.job_desc.str.replace('’', '')
df.job_desc = df.job_desc.str.replace('/', '')
df.job_desc = df.job_desc.str.replace('+', '')
df.job_desc = df.job_desc.str.replace('&', '')
df.job_desc = df.job_desc.str.replace("'", '')
df.job_desc = df.job_desc.str.replace('@', '')
df.job_desc = df.job_desc.str.replace(';', '')
df.job_desc = df.job_desc.str.replace('%', '')
df.job_desc = df.job_desc.str.replace('•', '')
df.job_desc = df.job_desc.str.replace('!', '')
df.job_desc = df.job_desc.str.replace('#', '')
df.job_desc = df.job_desc.str.replace(':', '')
df.job_desc = df.job_desc.str.replace('(', '')
df.job_desc = df.job_desc.str.replace(')', '')
df.job_desc = df.job_desc.str.replace('.', '')

# %%
X = df['job_desc']

# %%
y = df['pay_total2']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
stop = stopwords.words('english')

# %%
class LemmaTokenizer(object):
    def __init__(self):
        self.wnl = WordNetLemmatizer()
    def __call__(self, articles):
        return [self.wnl.lemmatize(t) for t in word_tokenize(articles)]

# %%
model2 = Pipeline(
            steps = [('tfidf', TfidfVectorizer(tokenizer=LemmaTokenizer(), 
                                               ngram_range=(1,2),
                                               stop_words=stop, 
                                               max_features=150,
                                               max_df = 0.5,
                                               sublinear_tf = True)), 
                      ('gs', GridSearchCV(RandomForestRegressor(),
                                          param_grid={'n_estimators': [520, 535, 550],
                                                      'max_depth' : [15,20,25]},
                                                      cv=5,
                                                      refit=True))]
                  )

model2.fit(X_train, y_train)
y_pred = model2.predict(X_test)

print(model2.score(X_test,y_test))
print("Number of features:", len(model2.steps[0][1].get_feature_names()))

# print(model.steps[0][1].get_feature_names())
# print(model.steps[1][1].feature_importances_)
# print(model.named_steps['rfc'].feature_importances_)


print(model2.steps[1][1].best_params_)

# %%
def RandomForest():
    model2 = Pipeline(
                steps = [('tfidf', TfidfVectorizer(tokenizer=LemmaTokenizer(), 
                                                   ngram_range=(1,2),
                                                   stop_words=stop, 
                                                   max_features=150,
                                                   max_df = 0.2,
                                                   sublinear_tf = True)), 
                          ('rfr', RandomForestRegressor(n_estimators=550,
                                                         max_depth=25,
                                                         random_state=42))]
                      )

    model2.fit(X_train, y_train)
    y_pred = model2.predict(X_test)

    print(model2.score(X_test,y_test))
    print("Number of features:", len(model2.steps[0][1].get_feature_names()))

    # print(model.steps[0][1].get_feature_names())
    # print(model.steps[1][1].feature_importances_)
    # print(model.named_steps['rfc'].feature_importances_)



    feature_importances = pd.DataFrame(model2.steps[1][1].feature_importances_, model2.steps[0][1].get_feature_names()).reset_index()
    feature_importances.columns = ['feature', 'importance']
    features = feature_importances.sort_values('importance', ascending=False)
    print(features.sort_values('importance', ascending=False).head(60))

# %%
stop.extend(["'d", "'ll", "'re", "'s", "'ve", 'could', 'doe', 'ha', 'might', 'must', "n't", 'need', 'sha', 
             'wa', 'wo', 'would', 'business', 'analyst', 'test', 'change', 'program', 'government', 'engineer',
             'contract', 'account', 'month', 'documentation', 'detail', 'implementation', 'deliver', 'following',
             'sale', 'identify', 'multiple', 'delivering', '02', 'plan', 'document', 'experienced', 'current', 'end',
             'growth', 'financial', 'service', 'button', 'demonstrated', 'cbd', 'nsw', '·', 'big', 'enterprise',
             'user', 'diverse', 'cv', 'testing', 'finance', 'problem', 'issue', 'skills', 'experience', 'future',
             'create', 'risk', 'engagement', 'policy', 'andor', 'experience', 'working', 'discussion', 'improve',
             'software', 'please', 'apply', 'meet', 'model', 'standard', 'skill', 'impact', 'initiative', 
             'sound', '5', 'confidential', 'qualification', 'intelligence', 'focus', 'training', 'understand',
             'essential', 'seeking', 'currently', 'operational', 'employment', '–', "''", 'outcome', 'administration',
             'super', 'case', 'advice', 'platform', 'send', 'best', 'framework', 'control', '2', 'ideal', 'review',
             'insurance', '3', 'effective', 'resource', 'analyse', 'implement', 'insight', 'department', 'attention',
             'assist', 'number', 'via', 'engineering', 'analytical', 'click', 'leader', 'call', 'operation',
             'infrastructure', 'strategic', 'operation', 'ability', 'work', 'use', 'challenge', 'relevant', 'source',
             'exposure', 'digital', 'available', 'capability', 'success', 'etc', 'minimum', 'data', 'analysis',
             'considered', 'international', 'maintain', 'expertise', 'internal', 'external', 'recruitment', 'target',
             'focused', 'great', 'next', 'proven', 'improvement', 'consulting', 'around', 'state', 'performing',
             'provider', 'asset', 'u', 'practice', 'campaign', 'background', 'closely', 'innovative', 'centre',
             'transformation', '?', 'developing', 'set', 'related', 'interested', 'successful', 'candidate',
             'medium', '6', 'approach', 'area', 'right', 'range', 'able', 'managing', 'eg', 'criterion', 
             'equivalent', 'budget', 'duty', 'format', 'dynamic', 'resume', 'interest', 'person', 'day', 'desirable',
             'start', 'offer', 'preferred', 'life', 'location', 'culture', 'critical', 'help', 'order', 'functional',
             'different', '4', 'get', 'regarded', 'methodology', 'perform', 'agency', 'compliance', 'ideally', 
             'operating', 'status', 'benefit', 'idea', 'various', 'make', 'writing', 'detailed', 'rate', 'fast',
             'corporate', 'track', 'planning', 'developer', 'unit', 'value', 'decision', 'someone', 'growing',
             'mapping', 'banking', 'national', 'used', 'procedure', 'directly', 'previous', 'extensive', 'major',
             'passionate', 'time', 'commercial', 'email', 'exciting', 'technique', 'youll', 'production', 'bonus', 
             'full', 'sector', 'good', 'assessment', 'concept', 'link', 'implementing', 'high', 'level', 'positive',
             'team', 'member', 'learn', 'communicate', 'key', 'stakeholder', 'basis', 'purpose', 'salary', 'equal',
             'group', 'demonstrate', 'providing', 'verbal', 'ensuring', ',', '1', '``', 'youre', 'architecture',
             'objective', 'significant', 'fantastic', 'specification', '2019', 'activity', 'ongoing', 'place', 
             'solving', 'brand', 'making', 'daily', 'written', 'communication', 'task', 'due', 'degree', 'see',
             'find', 'leadership', 'clear', 'integrity', 'latest', 'supportive', 'learning', 'wide', 'whats', 
             'relation', 'offering', 'accounting', 'expert', 'solid', 'maintaining', 'local', 'manager',
             'step', 'engage', 'record', 'web', 'monitoring', 'initial', 'note', 'power', 'balance', 'important', 
             'api', 'investment', 'reference', 'flexible', 'applicant', 'small', 'world', 'involved', 'profile',
             'present', 'personal', 'discipline', 'vendor'])

# %%
RandomForest()
# Out:
# 0.18331329880477054
# Number of features: 150
#                 feature  importance
# 5                 agile    0.068299
# 74          integration    0.057619
# 13                   ba    0.049483
# 14                 bank    0.045184
# 148                word    0.042148
# 114          regulatory    0.035620
# 108  project management    0.034265
# 21                cloud    0.033526
# 120            security    0.032134
# 127                 sql    0.029107
# 91            modelling    0.028922
# 11           automation    0.022667
# 110              python    0.022289
# 57                excel    0.017494
# 77           javascript    0.016980
# 18             capacity    0.014839
# 42             database    0.012819
# 144       visualisation    0.011660
# 6             analytics    0.010520
# 16                   bi    0.010060
# 93              network    0.009768
# 117              retail    0.009767
# 105             prepare    0.008879
# 99              payment    0.008690
# 76                 java    0.007894
# 138              timely    0.007555
# 41                  crm    0.007243
# 36           contribute    0.007191
# 131          supporting    0.007135
# 12                  aws    0.007112
# 96              package    0.006917
# 24          collaborate    0.006862
# 45                drive    0.006697
# 137            tertiary    0.006586
# 122             similar    0.006486
# 140               trend    0.006046
# 30             computer    0.006030
# 60             existing    0.005888
# 50            efficient    0.005829
# 4              advanced    0.005651
# 86            marketing    0.005431
# 47              driving    0.005135
# 8           appropriate    0.004958
# 106        presentation    0.004851
# 134                take    0.004821
# 85          maintenance    0.004569
# 90            microsoft    0.004512
# 63             function    0.004502
# 102           potential    0.004432
# 53             employee    0.004371
# 119             science    0.004329
# 56                event    0.004318
# 61                field    0.004312
# 58          exceptional    0.004253
# 2              accurate    0.004239
# 84              machine    0.004197
# 139                 top    0.004080
# 83                 love    0.004021
# 100           permanent    0.003894
# 136                term    0.003878
